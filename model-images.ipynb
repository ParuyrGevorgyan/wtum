# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import numpy as np
import os
from FileCounter import fileCount
import matplotlib.pyplot as plt
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/pro/wtum/model-images.ipynb Cell 1 in 9
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pro/wtum/model-images.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> from FileCounter import fileCount
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pro/wtum/model-images.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pro/wtum/model-images.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
trainData = 'asl-alphabet/asl_alphabet_train/asl_alphabet_train'
testData = 'asl-alphabet/asl_alphabet_test/asl_alphabet_test'

# %%
train_transforms =  transforms.Compose([
    transforms.Resize((200, 200)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

test_transforms = transforms.Compose([
    transforms.Resize((200, 200)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

train_dataset = datasets.ImageFolder(trainData, transform=train_transforms)
test_dataset = datasets.ImageFolder(testData, transform=test_transforms)

# %%
test_dataset[3]
# Out:
# (tensor([[[-2.1179, -2.1179, -2.0494,  ..., -1.9980, -2.1179, -2.1179],
#           [-2.1179, -2.1008, -1.9467,  ..., -1.8782, -2.0494, -2.1179],
#           [-2.0494, -1.9295, -1.4843,  ...,  0.3652, -0.0629, -1.8953],
#           ...,
#           [-2.0494, -2.0323, -0.3369,  ...,  0.4679,  0.0227, -1.8953],
#           [-2.1179, -2.0665, -0.6623,  ..., -0.0287, -0.4226, -1.9467],
#           [-2.1179, -2.0665, -2.0152,  ..., -1.8610, -1.9809, -2.0152]],
#
#          [[-1.9657, -1.9832, -2.0182,  ..., -2.0182, -2.0182, -1.9482],
#           [-2.0007, -2.0007, -1.9832,  ..., -1.9307, -1.9657, -2.0007],
#           [-2.0182, -1.9307, -1.5805,  ...,  0.2927, -0.0574, -1.8606],
#           ...,
#           [-2.0182, -1.9482, -0.1625,  ...,  0.4678,  0.0651, -1.8431],
#           [-2.0357, -1.9657, -0.5126,  ...,  0.0126, -0.3200, -1.8081],
#           [-1.9832, -1.9482, -1.8957,  ..., -1.8256, -1.8782, -1.8431]],
#
#          [[ 2.5703,  2.5180,  2.4134,  ...,  2.4308,  2.3960,  2.4483],
#           [ 2.5703,  2.3611,  1.9951,  ...,  1.7511,  1.9080,  1.9951],
#           [ 2.5529,  2.1171,  1.4548,  ...,  2.3437,  2.2391,  1.3328],
#           ...,
#           [ 2.4657,  1.7685,  2.0474,  ...,  1.7860,  2.2391,  0.8797],
#           [ 2.5354,  2.0474,  2.2914,  ...,  2.1868,  2.2391,  1.2980],
#           [ 2.5877,  2.2217,  1.4548,  ...,  0.9145,  1.2805,  1.4897]]]),
#  3)

# %%
image, label = test_dataset[3]

plt.imshow(image.permute(1, 2, 0))
plt.show()
print(label)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 3

# %%
image = cv2.imread("asl-alphabet/asl_alphabet_test/asl_alphabet_test/D/D_test.jpg")

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.show()

# %%
#CountOfTraining
A_path = 'asl-alphabet/asl_alphabet_train/asl_alphabet_train/A'
A_count = fileCount(A_path)
B_path = 'asl-alphabet/asl_alphabet_train/asl_alphabet_train/B'
B_count = fileCount(B_path)
B_count
# Out:
# 3000
